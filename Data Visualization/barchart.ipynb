# %%
import matplotlib.pyplot as plt

# %%
#Bar Chart
movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
years = [2008, 2009, 2010, 2011, 2012]
oscar_revenue = [1005, 170, 427, 133, 232] #in $M

plt.bar(years, oscar_revenue, color = "red")
plt.title("Revenue in each year for Oscar Movies")
plt.xlabel("Year")
plt.ylabel("Revenue (in $M)")


for i in range(len(years)):
    plt.text(years[i], oscar_revenue[i]+20, str(oscar_revenue[i]), ha= "center")


plt.ylim(0, max(oscar_revenue)+100)
plt.xlim(min(years), max(years)+5)
# Out:
# (2008.0, 2017.0)

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np

oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
oscar_revenue = [1005, 170, 427, 133, 232] #in $M


non_oscar_movies = ["Slumdog Millionaire", "Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue = [378, 2787, 829, 185, 275]

years = [2008, 2009, 2010, 2011, 2012]

x = np.arange(len(years))
width = 0.4

plt.bar(x-width/2, oscar_revenue, width, label="Oscar Movies")          #shifting to left
plt.bar(x+width/2, non_oscar_revenue, width, label="Non- Oscar Movies")     #shifting to right

plt.title("Oscar vs Non Oscar Movie Revenue")
plt.xlabel("Year")
plt.ylabel("Revenue (in $M)")
plt.legend()

# %%
import numpy as np

oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
oscar_revenue = [1005, 170, 427, 133, 232] #in $M


non_oscar_movies = ["Slumdog Millionaire", "Avatar","Inception","Hugo","Lincoln"]
non_oscar_revenue = [378, 2787, 829, 185, 275]

years = [2008, 2009, 2010, 2011, 2012]

x = np.arange(len(years))
width = 0.2

plt.bar(x-width, oscar_revenue, width, label="Oscar Movies")          #shifting to left
plt.bar(x, non_oscar_revenue, width, label="Non- Oscar Movies")     #shifting to right
plt.bar(x+width, non_oscar_revenue, width, label="Non- Oscar Movies")     #shifting to right

plt.title("Oscar vs Non Oscar Movie Revenue")
plt.xlabel("Year")
plt.ylabel("Revenue (in $M)")
plt.legend()


plt.xticks (x, years)
# Out:
# ([<matplotlib.axis.XTick at 0x1a8611cbd10>,
# ...
#  [Text(0, 0, '2008'),
#   Text(1, 0, '2009'),
#   Text(2, 0, '2010'),
#   Text(3, 0, '2011'),
#   Text(4, 0, '2012')])

# %%
# Horizontal Chart
oscar_movies = [
    "The Dark Knight",
    "The Hurt Locker",
    "The King's Speech",
    "The Artist",
    "Argo"
]
oscar_revenue = [1005, 170, 427, 133, 232] #in $M

plt.barh(oscar_movies, oscar_revenue)
plt.xlabel("Revenue")
plt.ylabel("Movies")
# Out:
# Text(0, 0.5, 'Movies')
